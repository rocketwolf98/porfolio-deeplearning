# %% [markdown]
# # Calculating Forward Pass <br>
# ### By Kenneth Lim

# %% [markdown]
# Thanks to Linear Algebra, we are now able to let computers be able to think like humans and to think like humans means someday we can destroy CAPTCHA or obliterate the Turing Test entirely. In this activity, we will explore a simple implementation on how do we calculate forward pass using a very simple representation just like how we overthink how a brain of person with high amounts of IQ work.

# %% [markdown]
# Given that we have:
#
# $$
# x =
# \begin{bmatrix}
# 1 \\
# 0 \\
# 1
# \end{bmatrix}
# $$
#
# $$
# y = [1]
# $$
#
# $$
# f = \max(0, Z_n)
# $$
#
# **hidden unit weights**
#
# $$
# \begin{bmatrix}
# w_{11} = 0.2 & w_{12} = -0.3 \\
# w_{13} = 0.4 & w_{14} = 0.1 \\
# w_{15} = -0.5 & w_{16} = 0.2
# \end{bmatrix}
# $$
#
# **output unit weights**
#
# $$
# \begin{bmatrix}
# w_{21} = -0.3 \\
# w_{22} = -0.2
# \end{bmatrix}
# $$
#
# **bias terms**
#
# $$
# \theta =
# \begin{bmatrix}
# \theta_1 = -0.4 \\
# \theta_2 = 0.2 \\
# \theta_3 = 0.1
# \end{bmatrix}
# $$

# %% [markdown]
# We will visualize this in a very comprehensible form

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. We wil start calculating our hidden layer. The dot product of the hidden layers are now shown sans the addition of bias.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.1. Given that we have:
#
# $$
# Z_1 = (0.2 + 0 + -0.5) - 0.4
# $$
#
# $$
# Z_2 = (-0.3 + 0 + 0.2) + 0.2
# $$
#
#
# We will obtain these by including the bias:
#
# $$
# Z_1 = -0.7
# $$
#
# $$
# Z_2 = 0.1
# $$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Applying fmax, we will be given that fact where:
#
# $$
# f=max(0,Z_n)
# $$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. We started calculating the output layers

# %% [markdown]
# Sans the bias:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We may achieved a y-output of 0.12
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# And to speak of the error, we got:
# $$
# y_{\text{error}} = 0.88
# $$
#
# Quite far from what we would like to predict as 1
